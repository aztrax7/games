# %% [markdown]
# <a href="https://colab.research.google.com/github/aztrax7/games/blob/main/dyso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("Welcome to Dyso, a game of chance! The 4 players are Green, Red, White and Blue. Each will roll a dice and whoever rolls a '6' first will win the game!!!")

while True:
  Green = random.randint(1,6)
  print("Green throws...")
  print("And gets:", Green)
  if Green == 6:
    print("Green has won the game!")
    break

  Red = random.randint(1,6)
  print("Red throws...")
  print("And gets:", Red)
  if Red == 6:
    print("Red has won the game!")
    break

  White = random.randint(1,6)
  print("White throws...")
  print("And gets:", White)
  if White == 6:
    print("White has won the game!")
    break

  Blue = random.randint(1,6)
  print("Blue throws...")
  print("And gets:", Blue)
  if Blue == 6:
    print("Blue has won the game!")
    break
